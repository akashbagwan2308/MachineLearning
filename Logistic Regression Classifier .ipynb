# %% [markdown]
# # Logistic Regression Classifier

# %% [markdown]
# ![logistic-regression-in-machine-learning.png](attachment:logistic-regression-in-machine-learning.png)

# %% [markdown]
# ![1_JHWL_71qml0kP_Imyx4zBg.webp](attachment:1_JHWL_71qml0kP_Imyx4zBg.webp)

# %% [markdown]
# Sigmoid Function : y = 1 / ( 1 + e^x )

# %% [markdown]
# **Problem Statement : Train a logistic regression classifier to predict whether a flower is iris virginica or not**

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading Dataset**

# %%
iris = datasets.load_iris()

# %%
print(list(iris.keys()))
# Out:
# ['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module']

# %%
# print(iris['data'])
# print(iris['target'])
# print(iris['DESCR'])

# %%
X = iris["data"][:,3:]
Y = (iris["target"]==2).astype(np.int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8008\211504731.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y = (iris["target"]==2).astype(np.int)

# %% [markdown]
# **Training A logistic regression classifier**

# %%
clf = LogisticRegression()
clf.fit(X,Y)
# Out:
# LogisticRegression()

# %% [markdown]
# **Making Prediction**

# %%
example = clf.predict(([[2.6]]))
print(example)
# Out:
# [1]

# %% [markdown]
# **Ploting the visualization**

# %%
X_new = np.linspace(0,3,1000).reshape(-1,1)
Y_prob = clf.predict_proba(X_new)

# %%
plt.plot(X_new,Y_prob[:,1],"g-",label = 'virginica')
plt.xlabel("X_New")
plt.ylabel("Probability")
plt.legend()
plt.show()
